# %% [markdown]
# # Análise de expressão facial com redes neurais
#
# #### MO444 - Aprendizado de Máquina e Reconhecimento de Padrões
#
# ______
#
# **Técnica**: Redes neurais.
#
# **Descrição**: Análise da expressão facial utilizando rede neural simples.
#
# **Data**: 14/11/2018
#
# **Bruno Silvério de Freitas** <br>
# **Fernanda Ribeiro**  <br>
# **Fernando Seiti Furusato** <br>
# **Gustavo J. Q. Vasconcelos**
# ______

# %% [markdown]
# # Importando Bibliotecas

# %%
# %matplotlib inline

import cv2

# Importar as bibliotecas
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import statsmodels.api as sm
import seaborn as sns
import os
import matplotlib.image as mpimg
import sys
import itertools
import tensorflow as tf
# import cv2

from scipy import signal as sg
from scipy import ndimage as sc
from sklearn import datasets, linear_model
from sklearn.metrics import mean_squared_error, r2_score, confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn import preprocessing

from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D
from keras.layers import Activation, Dropout, Flatten, Dense
from keras import backend as K
from keras.layers import Input
from keras.models import model_from_json
from keras.callbacks import TensorBoard, ModelCheckpoint, EarlyStopping, CSVLogger
from keras.utils import np_utils
from keras.optimizers import SGD, Adadelta
from keras import regularizers

# Exibir 10 linhas do conjunto de dados
pd.set_option("max_r",10)
pd.get_option("display.max_rows")

# Estilo do Gráfico
import matplotlib
matplotlib.style.use('ggplot')
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # Métricas
#
# Para esse trabalho avaliaremos a acurácia normalizada (por ser amostras desbalanceadas) e a matriz de confusão.

# %%
def accuracy_normalized(y_true,y_pred):
    mc = confusion_matrix(y_true,y_pred)
    mc_margin = np.sum(mc,axis = 1)

    n = len(mc)

    tp = []
    for i in range(n):
        tp.append(mc[i][i]/mc_margin[i])

    accuracy_normalized = np.sum(tp)/n 

    return accuracy_normalized

def acuracia(y_true,y_pred):
    mc = confusion_matrix(y_true,y_pred)
    mc_tot = np.sum(mc)
    n = len(mc)

    tp = []
    for i in range(n):
        tp.append(mc[i][i])

    accuracy = np.sum(tp)/mc_tot 

    return accuracy

def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Matriz de confusão',
                          cmap=plt.cm.Blues):
    
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title, fontsize=16)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45, fontsize=12)
    plt.yticks(tick_marks, classes, fontsize=12)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.ylabel('Observado', fontsize=14)
    plt.xlabel('Predito', fontsize=14)
    plt.tight_layout()

# %% [markdown]
# ____
#
# ## Base de dados
#
# Será utilizado o conjunto de dados `fer2013`, disponível no desafio do [Kaggle](https://www.kaggle.com/c/challenges-in-representation-learning-facial-expression-recognition-challenge).
#
# >The data consists of 48x48 pixel grayscale images of faces. The faces have been automatically registered so that the face is more or less centered and occupies about the same amount of space in each image. The task is to categorize each face based on the emotion shown in the facial expression in to one of seven categories (0=Angry, 1=Disgust, 2=Fear, 3=Happy, 4=Sad, 5=Surprise, 6=Neutral).
# <br><br>
#  train.csv contains two columns, "emotion" and "pixels". The "emotion" column contains a numeric code ranging from 0 to 6, inclusive, for the emotion that is present in the image. The "pixels" column contains a string surrounded in quotes for each image. The contents of this string a space-separated pixel values in row major order. test.csv contains only the "pixels" column and your task is to predict the emotion column.
# <br><br>
#  The training set consists of 28,709 examples. The public test set used for the leaderboard consists of 3,589 examples. The final test set, which was used to determine the winner of the competition, consists of another 3,589 examples.
# <br><br>
#  This dataset was prepared by Pierre-Luc Carrier and Aaron Courville, as part of an ongoing research project. They have graciously provided the workshop organizers with a preliminary version of their dataset to use for this contest.

# %%
# !pip install -U -q PyDrive

# from google.colab import auth
# auth.authenticate_user()

# from pydrive.drive import GoogleDrive
# from pydrive.auth import GoogleAuth
# from oauth2client.client import GoogleCredentials
# gauth = GoogleAuth()
# gauth.credentials = GoogleCredentials.get_application_default()
# drive = GoogleDrive(gauth)

# # https://drive.google.com/file/d/1VjmDEp_VATI3_qk4t3s1lVvqIBNQBr96/view?usp=sharing
# fer2013 = drive.CreateFile({'id': '1VjmDEp_VATI3_qk4t3s1lVvqIBNQBr96'})
# fer2013.GetContentFile('fer2013.csv')
# dados = pd.DataFrame(pd.read_csv('fer2013.csv'))

print(os.getcwd())
DIR = os.getcwd()
train_x = pd.DataFrame(pd.read_csv('Dados/train_down_resize_IMAGES.csv'))
train_y = pd.DataFrame(pd.read_csv('Dados/train_y_down_resize_IMAGES.csv'))
validation_x = pd.DataFrame(pd.read_csv('Dados/validation_down_resize_IMAGES.csv'))
validation_y = pd.DataFrame(pd.read_csv('Dados/validation_y_down_resize_IMAGES.csv'))
test_x = pd.DataFrame(pd.read_csv('Dados/test_down_resize_IMAGES.csv'))
test_y = pd.DataFrame(pd.read_csv('Dados/test_y_down_resize_IMAGES.csv'))
# Out:
# /home/ABTLUS/fernando.furusato/mo444a-final

# %% [markdown]
# ### Dimensão dos dados
# Avalia a dimensão do conjunto de dados e dos dados para modelagem

# %%
shape = 60

print('===================================')
print('          Dados originais          ')
print('===================================')
print('-----------------------------------')
print('Conjunto de treinamento:')
# train = train.sample(500)
train_x = np.vstack(train_x.values)
train_y.columns = ['Angry','Disgust','Fear','Happy','Sad','Surprise','Neutral']
print('X: {}, y: {}'.format(train_x.shape,train_y.shape))

print('-----------------------------------')
print('Conjunto de validação:')
validation_x = np.vstack(validation_x.values)
validation_y.columns = ['Angry','Disgust','Fear','Happy','Sad','Surprise','Neutral']
print('X: {}, y: {}'.format(validation_x.shape,validation_y.shape))

print('-----------------------------------')
print('Conjunto de teste:')
test_x = np.vstack(test_x.values)
test_y.columns = ['Angry','Disgust','Fear','Happy','Sad','Surprise','Neutral']
print('X: {}, y: {}'.format(test_x.shape,test_y.shape))
print('-----------------------------------')
print('===================================')

print('\n')
print('===================================')
print('       Dados para modelagem        ')
print('===================================')
print('-----------------------------------')
print('Conjunto de treinamento:')
train_x_conv = np.reshape(train_x,(-1, 1, shape, shape))
print('X: {}'.format(train_x_conv.shape))
print('-----------------------------------')
print('Conjunto de validação:')
validation_x_conv = np.reshape(validation_x,(-1, 1, shape, shape))
print('X: {}'.format(validation_x_conv.shape))
print('-----------------------------------')
print('Conjunto de teste:')
test_x_conv = np.reshape(test_x,(-1, 1, shape, shape))
print('X: {}'.format(test_x_conv.shape))
print('-----------------------------------')
print('===================================')
# Out:
# ===================================
#           Dados originais
# ===================================
# -----------------------------------
# Conjunto de treinamento:
# X: (20473, 3600), y: (20473, 7)
# -----------------------------------
# Conjunto de validação:
# X: (2560, 3600), y: (2560, 7)
# -----------------------------------
# Conjunto de teste:
# X: (3588, 3600), y: (3588, 7)
# -----------------------------------
# ===================================
#
#
# ===================================
#        Dados para modelagem
# ===================================
# -----------------------------------
# Conjunto de treinamento:
# X: (20473, 1, 60, 60)
# -----------------------------------
# Conjunto de validação:
# X: (2560, 1, 60, 60)
# -----------------------------------
# Conjunto de teste:
# X: (3588, 1, 60, 60)
# -----------------------------------
# ===================================

# %% [markdown]
# #### Exemplo do conjunto de dados de treinamento

# %%
fig, axs = plt.subplots(5,10, figsize=(19, 10), facecolor='w', edgecolor='k')
fig.subplots_adjust(hspace = .2, wspace=.0001)
axs = axs.ravel()

for i in range(50):
    axs[i].imshow(train_x_conv.squeeze()[i], cmap='gray')
    axs[i].set_title(train_y.loc[i,train_y.loc[i]==1].index[0])
    axs[i].axis('off')

# %% [markdown]
# ### Padronização do conjunto de dados

# %%
train_x_conv = train_x_conv.astype('float32') / 255
validation_x_conv  = validation_x_conv.astype('float32') / 255
test_x_conv = test_x_conv.astype('float32') / 255

# %%
num_classes = train_y.shape[1]
print(num_classes)

input_shape = (1, shape, shape)
# Out:
# 7

# %% [markdown]
# _____
# ## Rede Neural Convolucional
#
# Abaixo será implementada uma rede neural convolucional simples, a fim de avaliar previamente o desempenho no conjunto de dados e, posteriormente, outros modelos serão aplicados. Para abrir o ``Tensorboard``:

# %% [raw]
# https://cloud.google.com/tpu/docs/quickstart
# executar no prompt: tensorboard --logdir "E:/Mestrado/Disciplinas/201802 - MO444 - Aprendizado de Máquina e Reconhecimento de Padrões/Projeto/Programas/TensorBoard/"
# abrir no navegador http://<your-ip>:6006, no meu caso, http://desktop-4pqid90:6006/

# %%
def CNN_Simples(input_shape):
    
    model = Sequential()
    model.add(Conv2D(32, (5, 5), input_shape=input_shape, data_format="channels_first"))
    model.add(Activation('relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))

    model.add(Conv2D(64, (7, 7)))  
    model.add(Activation('relu'))
    model.add(Dropout(0.1))
    model.add(MaxPooling2D(pool_size=(2, 2)))

#     model.add(Conv2D(128, (3, 3)))
#     model.add(Activation('relu'))
#     model.add(Dropout(0.1))
#     model.add(MaxPooling2D(pool_size=(2, 2)))

    model.add(Flatten())

    model.add(Dense(512))
    model.add(Activation('relu'))
#     model.add(Dropout(0.5))

    model.add(Dense(256))
    model.add(Activation('relu'))
#     model.add(Dropout(0.5))

    model.add(Dense(num_classes))
    model.add(Activation('softmax')) #Probabilidade de cada classe
    
    return model

# %% [markdown]
# Camadas do modelo:

# %%
model = CNN_Simples(input_shape)
model.summary()
# Out:
# WARNING:tensorflow:From /home/ABTLUS/fernando.furusato/mo444a/jupyter/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /home/ABTLUS/fernando.furusato/mo444a/jupyter/lib/python3.6/site-packages/tensorflow/python/ops/nn_ops.py:2794: div (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Deprecated in favor of operator or tf.math.divide.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 32, 56, 56)        832
# _________________________________________________________________
# activation_1 (Activation)    (None, 32, 56, 56)        0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 16, 28, 56)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 10, 22, 64)        175680
# _________________________________________________________________
# activation_2 (Activation)    (None, 10, 22, 64)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 10, 22, 64)        0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 5, 11, 64)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 3520)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               1802752
# _________________________________________________________________
# activation_3 (Activation)    (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               131328
# _________________________________________________________________
# activation_4 (Activation)    (None, 256)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 7)                 1799
# _________________________________________________________________
# activation_5 (Activation)    (None, 7)                 0
# =================================================================
# Total params: 2,112,391
# Trainable params: 2,112,391
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Compilando o modelo

# %%
# https://www.davidtvs.com/keras-custom-metrics/

class AccNorm(object):
    def __init__(self, num_classes):
        super().__init__()
        self.num_classes = num_classes

    def acc_norm(self, y_true, y_pred):
        # Wraps np_mean_iou method and uses it as a TensorFlow op.
        # Takes numpy arrays as its arguments and returns numpy arrays as
        # its outputs.
        
        return tf.py_func(self.np_acc_norm, [y_true, y_pred], tf.float32)        

    
    def np_acc_norm(self, y_true, y_pred):
        # Compute the confusion matrix to get the number of true positives,
        # false positives, and false negatives
        # Convert predictions and target from categorical to integer format
        target = np.argmax(y_true, axis=-1).ravel()
        predicted = np.argmax(y_pred, axis=-1).ravel()

        # Trick from torchnet for bincounting 2 arrays together
        # https://github.com/pytorch/tnt/blob/master/torchnet/meter/confusionmeter.py
        x = predicted + self.num_classes * target
        bincount_2d = np.bincount(x.astype(np.int32), minlength=self.num_classes**2)
        assert bincount_2d.size == self.num_classes**2
        conf = bincount_2d.reshape((self.num_classes, self.num_classes))

        # Compute the IoU and mean IoU from the confusion matrix
        true_positive = np.diag(conf)
        total = np.sum(conf, 1)
        false_positive = np.sum(conf, 0) - true_positive
        false_negative = np.sum(conf, 1) - true_positive

        # Just in case we get a division by 0, ignore/hide the error and set the value to 0
        with np.errstate(divide='ignore', invalid='ignore'):
            iou = true_positive / total #(true_positive + false_positive + false_negative)
        iou[np.isnan(iou)] = 0
#         print('conf: \n', conf, '\n true_positive: \n', true_positive, '\n total: \n', total, '\n iou: \n',iou)
#         print('acc: ',np.mean(iou).astype(np.float32))
        return np.mean(iou).astype(np.float32)

num_classes = 7
acc_metric = AccNorm(num_classes)

# %%
# https://github.com/keras-team/keras/issues/10426
model.compile(loss='categorical_crossentropy', optimizer="adam", metrics=["accuracy",acc_metric.acc_norm])
# Out:
# WARNING:tensorflow:From <ipython-input-12-94ebf8555046>:13: py_func (from tensorflow.python.ops.script_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# tf.py_func is deprecated in TF V2. Instead, use
#     tf.py_function, which takes a python function which manipulates tf eager
#     tensors instead of numpy arrays. It's easy to convert a tf eager tensor to
#     an ndarray (just call tensor.numpy()) but having access to eager tensors
#     means `tf.py_function`s can use accelerators such as GPUs as well as
#     being differentiable using a gradient tape.

# %%
num_epoch = 500
num_batch = 1024

checkpointer   = ModelCheckpoint(filepath=os.path.join('./Modelos/cnn_simples2_emocoes_weights_preproc.h5'), verbose=1, save_best_only=True, monitor='val_acc_norm')
csv_logger     = CSVLogger(os.path.join('./Modelos/cnn_simples2_training_preproc.log'))
early_stopping = EarlyStopping(monitor='val_acc_norm', min_delta=0, patience=5, verbose=1, mode='max')
tensorboard = TensorBoard('./TensorBoard/CNN Simples 2 - Pré-processamento',  write_graph=True, write_images=False)

model_history = model.fit(train_x_conv, train_y, epochs=num_epoch, batch_size=num_batch, shuffle=True, validation_data=(validation_x_conv, validation_y), verbose=1, callbacks=[tensorboard, early_stopping, checkpointer, csv_logger])
# Out:
# Train on 20473 samples, validate on 2560 samples
# Epoch 1/500
# 20473/20473 [==============================] - 27s 1ms/step - loss: 1.5917 - acc: 0.3952 - acc_norm: 0.2788 - val_loss: 1.5734 - val_acc: 0.4164 - val_acc_norm: 0.3048
#
# Epoch 00001: val_acc_norm improved from -inf to 0.30482, saving model to ./Modelos/cnn_simples2_emocoes_weights_preproc.h5
# Epoch 2/500
# 20473/20473 [==============================] - 27s 1ms/step - loss: 1.5385 - acc: 0.4192 - acc_norm: 0.2989 - val_loss: 1.5125 - val_acc: 0.4293 - val_acc_norm: 0.3122
#
# Epoch 00002: val_acc_norm improved from 0.30482 to 0.31224, saving model to ./Modelos/cnn_simples2_emocoes_weights_preproc.h5
# Epoch 3/500
# 20473/20473 [==============================] - 27s 1ms/step - loss: 1.4889 - acc: 0.4381 - acc_norm: 0.3165 - val_loss: 1.4857 - val_acc: 0.4504 - val_acc_norm: 0.3476
#
# Epoch 00003: val_acc_norm improved from 0.31224 to 0.34764, saving model to ./Modelos/cnn_simples2_emocoes_weights_preproc.h5
# Epoch 4/500
# 20473/20473 [==============================] - 27s 1ms/step - loss: 1.4522 - acc: 0.4571 - acc_norm: 0.3368 - val_loss: 1.4396 - val_acc: 0.4609 - val_acc_norm: 0.3492
#
# Epoch 00004: val_acc_norm improved from 0.34764 to 0.34916, saving model to ./Modelos/cnn_simples2_emocoes_weights_preproc.h5
# Epoch 5/500
# 20473/20473 [==============================] - 28s 1ms/step - loss: 1.4067 - acc: 0.4779 - acc_norm: 0.3553 - val_loss: 1.3856 - val_acc: 0.4813 - val_acc_norm: 0.3646
#
# Epoch 00005: val_acc_norm improved from 0.34916 to 0.36457, saving model to ./Modelos/cnn_simples2_emocoes_weights_preproc.h5
# Epoch 6/500
# 20473/20473 [==============================] - 27s 1ms/step - loss: 1.3774 - acc: 0.4890 - acc_norm: 0.3666 - val_loss: 1.3751 - val_acc: 0.4793 - val_acc_norm: 0.3646
#
# Epoch 00006: val_acc_norm did not improve from 0.36457
# Epoch 7/500
# 20473/20473 [==============================] - 28s 1ms/step - loss: 1.3581 - acc: 0.4962 - acc_norm: 0.3752 - val_loss: 1.3619 - val_acc: 0.4840 - val_acc_norm: 0.3750
#
# Epoch 00007: val_acc_norm improved from 0.36457 to 0.37498, saving model to ./Modelos/cnn_simples2_emocoes_weights_preproc.h5
# Epoch 8/500
# 20473/20473 [==============================] - 27s 1ms/step - loss: 1.3191 - acc: 0.5109 - acc_norm: 0.3890 - val_loss: 1.3361 - val_acc: 0.4941 - val_acc_norm: 0.3718
#
# Epoch 00008: val_acc_norm did not improve from 0.37498
# Epoch 9/500
# 20473/20473 [==============================] - 27s 1ms/step - loss: 1.3017 - acc: 0.5154 - acc_norm: 0.3931 - val_loss: 1.3169 - val_acc: 0.4953 - val_acc_norm: 0.3847
#
# Epoch 00009: val_acc_norm improved from 0.37498 to 0.38466, saving model to ./Modelos/cnn_simples2_emocoes_weights_preproc.h5
# Epoch 10/500
# 20473/20473 [==============================] - 28s 1ms/step - loss: 1.2965 - acc: 0.5170 - acc_norm: 0.3973 - val_loss: 1.3005 - val_acc: 0.5027 - val_acc_norm: 0.3921
#
# Epoch 00010: val_acc_norm improved from 0.38466 to 0.39207, saving model to ./Modelos/cnn_simples2_emocoes_weights_preproc.h5
# Epoch 11/500
# 20473/20473 [==============================] - 28s 1ms/step - loss: 1.2699 - acc: 0.5258 - acc_norm: 0.4043 - val_loss: 1.3013 - val_acc: 0.5004 - val_acc_norm: 0.3939
#
# Epoch 00011: val_acc_norm improved from 0.39207 to 0.39386, saving model to ./Modelos/cnn_simples2_emocoes_weights_preproc.h5
# Epoch 12/500
# 20473/20473 [==============================] - 27s 1ms/step - loss: 1.2538 - acc: 0.5305 - acc_norm: 0.4086 - val_loss: 1.2904 - val_acc: 0.5043 - val_acc_norm: 0.3939
#
# Epoch 00012: val_acc_norm improved from 0.39386 to 0.39389, saving model to ./Modelos/cnn_simples2_emocoes_weights_preproc.h5
# Epoch 13/500
# 20473/20473 [==============================] - 27s 1ms/step - loss: 1.2468 - acc: 0.5349 - acc_norm: 0.4141 - val_loss: 1.2858 - val_acc: 0.5168 - val_acc_norm: 0.4068
#
# Epoch 00013: val_acc_norm improved from 0.39389 to 0.40676, saving model to ./Modelos/cnn_simples2_emocoes_weights_preproc.h5
# Epoch 14/500
# 20473/20473 [==============================] - 27s 1ms/step - loss: 1.2399 - acc: 0.5399 - acc_norm: 0.4229 - val_loss: 1.2632 - val_acc: 0.5195 - val_acc_norm: 0.4074
#
# Epoch 00014: val_acc_norm improved from 0.40676 to 0.40740, saving model to ./Modelos/cnn_simples2_emocoes_weights_preproc.h5
# Epoch 15/500
# 20473/20473 [==============================] - 27s 1ms/step - loss: 1.2168 - acc: 0.5435 - acc_norm: 0.4262 - val_loss: 1.2439 - val_acc: 0.5227 - val_acc_norm: 0.4131
#
# Epoch 00015: val_acc_norm improved from 0.40740 to 0.41312, saving model to ./Modelos/cnn_simples2_emocoes_weights_preproc.h5
# Epoch 16/500
# 20473/20473 [==============================] - 27s 1ms/step - loss: 1.1981 - acc: 0.5542 - acc_norm: 0.4355 - val_loss: 1.2614 - val_acc: 0.5148 - val_acc_norm: 0.4138
#
# Epoch 00016: val_acc_norm improved from 0.41312 to 0.41380, saving model to ./Modelos/cnn_simples2_emocoes_weights_preproc.h5
# Epoch 17/500
# 20473/20473 [==============================] - 28s 1ms/step - loss: 1.1832 - acc: 0.5579 - acc_norm: 0.4439 - val_loss: 1.2478 - val_acc: 0.5203 - val_acc_norm: 0.4207
#
# Epoch 00017: val_acc_norm improved from 0.41380 to 0.42071, saving model to ./Modelos/cnn_simples2_emocoes_weights_preproc.h5
# Epoch 18/500
# 20473/20473 [==============================] - 27s 1ms/step - loss: 1.1719 - acc: 0.5634 - acc_norm: 0.4542 - val_loss: 1.2456 - val_acc: 0.5262 - val_acc_norm: 0.4228
#
# Epoch 00018: val_acc_norm improved from 0.42071 to 0.42283, saving model to ./Modelos/cnn_simples2_emocoes_weights_preproc.h5
# Epoch 19/500
# 20473/20473 [==============================] - 28s 1ms/step - loss: 1.1633 - acc: 0.5657 - acc_norm: 0.4530 - val_loss: 1.2363 - val_acc: 0.5293 - val_acc_norm: 0.4201
#
# Epoch 00019: val_acc_norm did not improve from 0.42283
# Epoch 20/500
# 20473/20473 [==============================] - 29s 1ms/step - loss: 1.1512 - acc: 0.5732 - acc_norm: 0.4679 - val_loss: 1.2141 - val_acc: 0.5336 - val_acc_norm: 0.4368
#
# Epoch 00020: val_acc_norm improved from 0.42283 to 0.43682, saving model to ./Modelos/cnn_simples2_emocoes_weights_preproc.h5
# Epoch 21/500
# 20473/20473 [==============================] - 29s 1ms/step - loss: 1.1385 - acc: 0.5780 - acc_norm: 0.4703 - val_loss: 1.2357 - val_acc: 0.5297 - val_acc_norm: 0.4299
#
# Epoch 00021: val_acc_norm did not improve from 0.43682
# Epoch 22/500
# 20473/20473 [==============================] - 29s 1ms/step - loss: 1.1337 - acc: 0.5786 - acc_norm: 0.4748 - val_loss: 1.2293 - val_acc: 0.5316 - val_acc_norm: 0.4341
#
# Epoch 00022: val_acc_norm did not improve from 0.43682
# Epoch 23/500
# 20473/20473 [==============================] - 27s 1ms/step - loss: 1.1122 - acc: 0.5864 - acc_norm: 0.4822 - val_loss: 1.2077 - val_acc: 0.5422 - val_acc_norm: 0.4322
#
# Epoch 00023: val_acc_norm did not improve from 0.43682
# Epoch 24/500
# 20473/20473 [==============================] - 28s 1ms/step - loss: 1.0921 - acc: 0.5941 - acc_norm: 0.4934 - val_loss: 1.2079 - val_acc: 0.5434 - val_acc_norm: 0.4430
#
# Epoch 00024: val_acc_norm improved from 0.43682 to 0.44297, saving model to ./Modelos/cnn_simples2_emocoes_weights_preproc.h5
# Epoch 25/500
# 20473/20473 [==============================] - 27s 1ms/step - loss: 1.0835 - acc: 0.5946 - acc_norm: 0.4951 - val_loss: 1.2157 - val_acc: 0.5422 - val_acc_norm: 0.4489
#
# Epoch 00025: val_acc_norm improved from 0.44297 to 0.44892, saving model to ./Modelos/cnn_simples2_emocoes_weights_preproc.h5
# Epoch 26/500
# 20473/20473 [==============================] - 27s 1ms/step - loss: 1.0671 - acc: 0.6038 - acc_norm: 0.5096 - val_loss: 1.2133 - val_acc: 0.5426 - val_acc_norm: 0.4633
#
# Epoch 00026: val_acc_norm improved from 0.44892 to 0.46326, saving model to ./Modelos/cnn_simples2_emocoes_weights_preproc.h5
# Epoch 27/500
# 20473/20473 [==============================] - 27s 1ms/step - loss: 1.0444 - acc: 0.6119 - acc_norm: 0.5190 - val_loss: 1.2086 - val_acc: 0.5426 - val_acc_norm: 0.4586
#
# Epoch 00027: val_acc_norm did not improve from 0.46326
# Epoch 28/500
# 20473/20473 [==============================] - 27s 1ms/step - loss: 1.0322 - acc: 0.6172 - acc_norm: 0.5233 - val_loss: 1.2053 - val_acc: 0.5512 - val_acc_norm: 0.4613
#
# Epoch 00028: val_acc_norm did not improve from 0.46326
# Epoch 29/500
# 20473/20473 [==============================] - 27s 1ms/step - loss: 1.0142 - acc: 0.6279 - acc_norm: 0.5383 - val_loss: 1.1922 - val_acc: 0.5527 - val_acc_norm: 0.4515
#
# Epoch 00029: val_acc_norm did not improve from 0.46326
# Epoch 30/500
# 20473/20473 [==============================] - 28s 1ms/step - loss: 0.9971 - acc: 0.6297 - acc_norm: 0.5424 - val_loss: 1.2105 - val_acc: 0.5461 - val_acc_norm: 0.4713
#
# Epoch 00030: val_acc_norm improved from 0.46326 to 0.47129, saving model to ./Modelos/cnn_simples2_emocoes_weights_preproc.h5
# Epoch 31/500
# 20473/20473 [==============================] - 27s 1ms/step - loss: 0.9893 - acc: 0.6346 - acc_norm: 0.5538 - val_loss: 1.2153 - val_acc: 0.5520 - val_acc_norm: 0.4640
#
# Epoch 00031: val_acc_norm did not improve from 0.47129
# Epoch 32/500
# 20473/20473 [==============================] - 27s 1ms/step - loss: 0.9794 - acc: 0.6382 - acc_norm: 0.5591 - val_loss: 1.2310 - val_acc: 0.5375 - val_acc_norm: 0.4710
#
# Epoch 00032: val_acc_norm did not improve from 0.47129
# Epoch 33/500
# 20473/20473 [==============================] - 27s 1ms/step - loss: 0.9734 - acc: 0.6417 - acc_norm: 0.5652 - val_loss: 1.2148 - val_acc: 0.5535 - val_acc_norm: 0.4669
#
# Epoch 00033: val_acc_norm did not improve from 0.47129
# Epoch 34/500
# 20473/20473 [==============================] - 27s 1ms/step - loss: 0.9535 - acc: 0.6456 - acc_norm: 0.5732 - val_loss: 1.1967 - val_acc: 0.5516 - val_acc_norm: 0.4677
#
# Epoch 00034: val_acc_norm did not improve from 0.47129
# Epoch 35/500
# 20473/20473 [==============================] - 27s 1ms/step - loss: 0.9295 - acc: 0.6582 - acc_norm: 0.5886 - val_loss: 1.2110 - val_acc: 0.5551 - val_acc_norm: 0.4961
#
# Epoch 00035: val_acc_norm improved from 0.47129 to 0.49605, saving model to ./Modelos/cnn_simples2_emocoes_weights_preproc.h5
# Epoch 36/500
# 20473/20473 [==============================] - 28s 1ms/step - loss: 0.9318 - acc: 0.6574 - acc_norm: 0.5878 - val_loss: 1.2273 - val_acc: 0.5484 - val_acc_norm: 0.4738
#
# Epoch 00036: val_acc_norm did not improve from 0.49605
# Epoch 37/500
# 20473/20473 [==============================] - 27s 1ms/step - loss: 0.8990 - acc: 0.6726 - acc_norm: 0.6048 - val_loss: 1.2301 - val_acc: 0.5441 - val_acc_norm: 0.4732
#
# Epoch 00037: val_acc_norm did not improve from 0.49605
# Epoch 38/500
# 20473/20473 [==============================] - 27s 1ms/step - loss: 0.8703 - acc: 0.6844 - acc_norm: 0.6191 - val_loss: 1.2306 - val_acc: 0.5480 - val_acc_norm: 0.4769
#
# Epoch 00038: val_acc_norm did not improve from 0.49605
# Epoch 39/500
# 20473/20473 [==============================] - 28s 1ms/step - loss: 0.8512 - acc: 0.6876 - acc_norm: 0.6271 - val_loss: 1.2249 - val_acc: 0.5602 - val_acc_norm: 0.4992
#
# Epoch 00039: val_acc_norm improved from 0.49605 to 0.49917, saving model to ./Modelos/cnn_simples2_emocoes_weights_preproc.h5
# Epoch 40/500
# 20473/20473 [==============================] - 27s 1ms/step - loss: 0.8289 - acc: 0.6971 - acc_norm: 0.6411 - val_loss: 1.2419 - val_acc: 0.5613 - val_acc_norm: 0.5036
#
# Epoch 00040: val_acc_norm improved from 0.49917 to 0.50360, saving model to ./Modelos/cnn_simples2_emocoes_weights_preproc.h5
# Epoch 41/500
# 20473/20473 [==============================] - 28s 1ms/step - loss: 0.8097 - acc: 0.7061 - acc_norm: 0.6601 - val_loss: 1.2453 - val_acc: 0.5535 - val_acc_norm: 0.4786
#
# Epoch 00041: val_acc_norm did not improve from 0.50360
# Epoch 42/500
# 20473/20473 [==============================] - 27s 1ms/step - loss: 0.8078 - acc: 0.7098 - acc_norm: 0.6537 - val_loss: 1.2383 - val_acc: 0.5551 - val_acc_norm: 0.4994
#
# Epoch 00042: val_acc_norm did not improve from 0.50360
# Epoch 43/500
# 20473/20473 [==============================] - 29s 1ms/step - loss: 0.8234 - acc: 0.7013 - acc_norm: 0.6513 - val_loss: 1.2729 - val_acc: 0.5477 - val_acc_norm: 0.5024
#
# Epoch 00043: val_acc_norm did not improve from 0.50360
# Epoch 44/500
# 20473/20473 [==============================] - 29s 1ms/step - loss: 0.7851 - acc: 0.7125 - acc_norm: 0.6638 - val_loss: 1.2640 - val_acc: 0.5648 - val_acc_norm: 0.5014
#
# Epoch 00044: val_acc_norm did not improve from 0.50360
# Epoch 45/500
# 20473/20473 [==============================] - 31s 2ms/step - loss: 0.7461 - acc: 0.7275 - acc_norm: 0.6829 - val_loss: 1.2904 - val_acc: 0.5551 - val_acc_norm: 0.4795
#
# Epoch 00045: val_acc_norm did not improve from 0.50360
# Epoch 00045: early stopping

# %%
# Probabilidades de cada classe
predito = model.predict_classes(train_x_conv)
predito_new = model.predict_classes(validation_x_conv)

obs = np.argmax(train_y.values,axis=1)
obs_new = np.argmax(validation_y.values,axis=1)

classes = ['Angry','Disgust','Fear','Happy','Sad','Surprise','Neutral']

# %% [markdown]
# ### Calcula a matriz de confusão:

# %%
fig1, axes1 = plt.subplots(nrows=1, ncols=1,figsize=(12,6))
graf_confusion_new = plot_confusion_matrix(confusion_matrix(obs,predito), normalize = False, classes=classes,title="Matriz de confusão - Treinamento")
axes1.grid(b=False)

fig2, axes2 = plt.subplots(nrows=1, ncols=1,figsize=(12,6))
graf_confusion_new = plot_confusion_matrix(confusion_matrix(obs_new,predito_new), normalize = False, classes=classes,title="Matriz de confusão - Validação")
axes2.grid(b=False)

# %% [markdown]
# ### Gráfico das métricas em cada epoch

# %%
fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(25,5))
plt.suptitle('Desempenho para o conjunto de treinamento e validação', fontsize=15, fontweight='bold')
axes[0].plot(model_history.history['loss'],marker='.')
axes[0].plot(model_history.history['val_loss'],marker='.')
axes[0].set_title('Função de Perda')
axes[0].set_ylabel('Loss')
axes[0].set_xlabel('Epoch')
axes[0].legend(['Treinamento', 'Validação'], loc='upper right')

axes[1].plot(model_history.history['acc'],marker='.')
axes[1].plot(model_history.history['val_acc'],marker='.')
axes[1].set_title('Acurácia')
axes[1].set_ylabel('Acurácia')
axes[1].set_xlabel('Epoch')
axes[1].legend(['Treinamento', 'Validação'], loc='upper left')

axes[2].plot(model_history.history['acc_norm'],marker='.')
axes[2].plot(model_history.history['val_acc_norm'],marker='.')
axes[2].set_title('Acurácia Normalizada')
axes[2].set_ylabel('Acurácia Normalizada')
axes[2].set_xlabel('Epoch')
axes[2].legend(['Treinamento', 'Validação'], loc='upper left')

# %% [markdown]
# ------
# ## Aplicando o modelo no conjunto de teste

# %%
from keras.models import load_model

# returns a compiled model identical to the previous one
model = load_model('./Modelos/cnn_simples2_emocoes_weights_preproc.h5', custom_objects={'acc_norm': acc_metric.acc_norm})

# %%
# Probabilidades de cada classe
predito = model.predict_classes(train_x_conv)
predito_new = model.predict_classes(validation_x_conv)
predito_new_tst = model.predict_classes(test_x_conv)

obs = np.argmax(train_y.values,axis=1)
obs_new = np.argmax(validation_y.values,axis=1)
obs_new_tst = np.argmax(test_y.values,axis=1)

classes = ['Angry','Disgust','Fear','Happy','Sad','Surprise','Neutral']

fig1, axes1 = plt.subplots(nrows=1, ncols=1,figsize=(12,6))
graf_confusion_new = plot_confusion_matrix(confusion_matrix(obs,predito), normalize = False, classes=classes,title="Matriz de confusão - Treinamento pré-processado (CNN)")
axes1.grid(b=False)

fig2, axes2 = plt.subplots(nrows=1, ncols=1,figsize=(12,6))
graf_confusion_new = plot_confusion_matrix(confusion_matrix(obs_new,predito_new), normalize = False, classes=classes,title="Matriz de confusão - Validação pré-processado (CNN)")
axes2.grid(b=False)

fig3, axes3 = plt.subplots(nrows=1, ncols=1,figsize=(12,6))
graf_confusion_new = plot_confusion_matrix(confusion_matrix(obs_new_tst,predito_new_tst), normalize = False, classes=classes,title="Matriz de confusão - Teste pré-processado (CNN)")
axes3.grid(b=False)

# %% [markdown]
# ### Conjunto de dados sem modificação

# %%
dados = pd.DataFrame(pd.read_csv('Dados/fer2013/fer2013.csv'))
dados['pixels'] = dados['pixels'].apply(lambda x: np.fromstring(x,sep=' '))

# %%
print('===================================')
print('          Dados originais          ')
print('===================================')
print('-----------------------------------')
print('Conjunto de teste:')
test = dados.loc[dados['Usage'] == 'PrivateTest']
# test = test.sample(300)
test_x = np.vstack(test['pixels'].values)
test_y = pd.get_dummies(test['emotion'])
test_y.columns = ['Angry','Disgust','Fear','Happy','Sad','Surprise','Neutral']
print('X: {}, y: {}'.format(test_x.shape,test_y.shape))
print('-----------------------------------')
print('===================================')

print('\n')
print('===================================')
print('       Dados para modelagem        ')
print('===================================')
print('-----------------------------------')
print('Conjunto de teste:')
test_x_conv = np.reshape(test_x,(-1, 48, 48))
print('X: {}'.format(test_x_conv.shape))
print('-----------------------------------')
print('===================================')
# Out:
# ===================================
#           Dados originais
# ===================================
# -----------------------------------
# Conjunto de teste:
# X: (3589, 2304), y: (3589, 7)
# -----------------------------------
# ===================================
#
#
# ===================================
#        Dados para modelagem
# ===================================
# -----------------------------------
# Conjunto de teste:
# X: (3589, 48, 48)
# -----------------------------------
# ===================================

# %%
shape_new = 60

test_x_alt = []

for im_test in test_x_conv:
    test_x_alt.append(cv2.resize(np.asarray(im_test), (shape_new,shape_new),interpolation=cv2.INTER_CUBIC))
    
test_x_conv = np.asarray(test_x_alt).astype('float32')/ 255
test_x_conv = np.reshape(test_x_conv,(-1, 1, shape_new, shape_new))    

# Probabilidades de cada classe
predito_new_tst = model.predict_classes(test_x_conv)
obs_new_tst = np.argmax(test_y.values,axis=1)

classes = ['Angry','Disgust','Fear','Happy','Sad','Surprise','Neutral']

fig1, axes1 = plt.subplots(nrows=1, ncols=1,figsize=(12,6))
graf_confusion_new = plot_confusion_matrix(confusion_matrix(obs_new_tst,predito_new_tst), normalize = False, classes=classes,title="Matriz de confusão - Teste")
axes1.grid(b=False)
