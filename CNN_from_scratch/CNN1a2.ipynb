# %% [markdown]
# # Análise de expressão facial com redes neurais
#
# #### MO444 - Aprendizado de Máquina e Reconhecimento de Padrões
#
# ______
#
# **Técnica**: Redes neurais.
#
# **Descrição**: Análise da expressão facial utilizando rede neural simples.
#
# **Data**: 14/11/2018
#
# **Bruno Silvério de Freitas** <br>
# **Fernanda Ribeiro** <br>
# **Fernando Seiti Furusato** <br>
# **Gustavo J. Q. Vasconcelos**
# ______

# %% [markdown]
# # Importando Bibliotecas

# %%
# %matplotlib inline

import cv2

# Importar as bibliotecas
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import statsmodels.api as sm
import seaborn as sns
import os
import matplotlib.image as mpimg
import sys
import itertools
import tensorflow as tf
# import cv2

from scipy import signal as sg
from scipy import ndimage as sc
from sklearn import datasets, linear_model
from sklearn.metrics import mean_squared_error, r2_score, confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn import preprocessing

from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D
from keras.layers import Activation, Dropout, Flatten, Dense
from keras import backend as K
from keras.layers import Input
from keras.models import model_from_json
from keras.callbacks import TensorBoard, ModelCheckpoint, EarlyStopping, CSVLogger
from keras.utils import np_utils
from keras.optimizers import SGD, Adadelta
from keras import regularizers

# Exibir 10 linhas do conjunto de dados
pd.set_option("max_r",10)
pd.get_option("display.max_rows")

# Estilo do Gráfico
import matplotlib
matplotlib.style.use('ggplot')
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # Métricas
#
# Para esse trabalho avaliaremos a acurácia normalizada (por ser amostras desbalanceadas) e a matriz de confusão.

# %%
def accuracy_normalized(y_true,y_pred):
    mc = confusion_matrix(y_true,y_pred)
    mc_margin = np.sum(mc,axis = 1)

    n = len(mc)

    tp = []
    for i in range(n):
        tp.append(mc[i][i]/mc_margin[i])

    accuracy_normalized = np.sum(tp)/n 

    return accuracy_normalized

def acuracia(y_true,y_pred):
    mc = confusion_matrix(y_true,y_pred)
    mc_tot = np.sum(mc)
    n = len(mc)

    tp = []
    for i in range(n):
        tp.append(mc[i][i])

    accuracy = np.sum(tp)/mc_tot 

    return accuracy

def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Matriz de confusão',
                          cmap=plt.cm.Blues):
    
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title, fontsize=16)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45, fontsize=12)
    plt.yticks(tick_marks, classes, fontsize=12)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.ylabel('Observado', fontsize=14)
    plt.xlabel('Predito', fontsize=14)
    plt.tight_layout()

# %% [markdown]
# ____
#
# ## Base de dados
#
# Será utilizado o conjunto de dados `fer2013`, disponível no desafio do [Kaggle](https://www.kaggle.com/c/challenges-in-representation-learning-facial-expression-recognition-challenge).
#
# >The data consists of 48x48 pixel grayscale images of faces. The faces have been automatically registered so that the face is more or less centered and occupies about the same amount of space in each image. The task is to categorize each face based on the emotion shown in the facial expression in to one of seven categories (0=Angry, 1=Disgust, 2=Fear, 3=Happy, 4=Sad, 5=Surprise, 6=Neutral).
# <br><br>
#  train.csv contains two columns, "emotion" and "pixels". The "emotion" column contains a numeric code ranging from 0 to 6, inclusive, for the emotion that is present in the image. The "pixels" column contains a string surrounded in quotes for each image. The contents of this string a space-separated pixel values in row major order. test.csv contains only the "pixels" column and your task is to predict the emotion column.
# <br><br>
#  The training set consists of 28,709 examples. The public test set used for the leaderboard consists of 3,589 examples. The final test set, which was used to determine the winner of the competition, consists of another 3,589 examples.
# <br><br>
#  This dataset was prepared by Pierre-Luc Carrier and Aaron Courville, as part of an ongoing research project. They have graciously provided the workshop organizers with a preliminary version of their dataset to use for this contest.

# %%
# !pip install -U -q PyDrive

# from google.colab import auth
# auth.authenticate_user()

# from pydrive.drive import GoogleDrive
# from pydrive.auth import GoogleAuth
# from oauth2client.client import GoogleCredentials
# gauth = GoogleAuth()
# gauth.credentials = GoogleCredentials.get_application_default()
# drive = GoogleDrive(gauth)

# # https://drive.google.com/file/d/1VjmDEp_VATI3_qk4t3s1lVvqIBNQBr96/view?usp=sharing
# fer2013 = drive.CreateFile({'id': '1VjmDEp_VATI3_qk4t3s1lVvqIBNQBr96'})
# fer2013.GetContentFile('fer2013.csv')
# dados = pd.DataFrame(pd.read_csv('fer2013.csv'))

print(os.getcwd())
DIR = os.getcwd()
train_x = pd.DataFrame(pd.read_csv('Dados/train_down_resize_IMAGES.csv'))
train_y = pd.DataFrame(pd.read_csv('Dados/train_y_down_resize_IMAGES.csv'))
validation_x = pd.DataFrame(pd.read_csv('Dados/validation_down_resize_IMAGES.csv'))
validation_y = pd.DataFrame(pd.read_csv('Dados/validation_y_down_resize_IMAGES.csv'))
test_x = pd.DataFrame(pd.read_csv('Dados/test_down_resize_IMAGES.csv'))
test_y = pd.DataFrame(pd.read_csv('Dados/test_y_down_resize_IMAGES.csv'))
# Out:
# E:\Mestrado\Disciplinas\201802 - MO444 - Aprendizado de Máquina e Reconhecimento de Padrões\Projeto\Programas

# %% [markdown]
# ### Dimensão dos dados
# Avalia a dimensão do conjunto de dados e dos dados para modelagem

# %%
shape = 60

print('===================================')
print('          Dados originais          ')
print('===================================')
print('-----------------------------------')
print('Conjunto de treinamento:')
# train = train.sample(500)
train_x = np.vstack(train_x.values)
train_y.columns = ['Angry','Disgust','Fear','Happy','Sad','Surprise','Neutral']
print('X: {}, y: {}'.format(train_x.shape,train_y.shape))

print('-----------------------------------')
print('Conjunto de validação:')
validation_x = np.vstack(validation_x.values)
validation_y.columns = ['Angry','Disgust','Fear','Happy','Sad','Surprise','Neutral']
print('X: {}, y: {}'.format(validation_x.shape,validation_y.shape))

print('-----------------------------------')
print('Conjunto de teste:')
test_x = np.vstack(test_x.values)
test_y.columns = ['Angry','Disgust','Fear','Happy','Sad','Surprise','Neutral']
print('X: {}, y: {}'.format(test_x.shape,test_y.shape))
print('-----------------------------------')
print('===================================')

print('\n')
print('===================================')
print('       Dados para modelagem        ')
print('===================================')
print('-----------------------------------')
print('Conjunto de treinamento:')
train_x_conv = np.reshape(train_x,(-1, 1, shape, shape))
print('X: {}'.format(train_x_conv.shape))
print('-----------------------------------')
print('Conjunto de validação:')
validation_x_conv = np.reshape(validation_x,(-1, 1, shape, shape))
print('X: {}'.format(validation_x_conv.shape))
print('-----------------------------------')
print('Conjunto de teste:')
test_x_conv = np.reshape(test_x,(-1, 1, shape, shape))
print('X: {}'.format(test_x_conv.shape))
print('-----------------------------------')
print('===================================')
# Out:
# ===================================
#           Dados originais
# ===================================
# -----------------------------------
# Conjunto de treinamento:
# X: (20473, 3600), y: (20473, 7)
# -----------------------------------
# Conjunto de validação:
# X: (2560, 3600), y: (2560, 7)
# -----------------------------------
# Conjunto de teste:
# X: (3588, 3600), y: (3588, 7)
# -----------------------------------
# ===================================
#
#
# ===================================
#        Dados para modelagem
# ===================================
# -----------------------------------
# Conjunto de treinamento:
# X: (20473, 1, 60, 60)
# -----------------------------------
# Conjunto de validação:
# X: (2560, 1, 60, 60)
# -----------------------------------
# Conjunto de teste:
# X: (3588, 1, 60, 60)
# -----------------------------------
# ===================================

# %% [markdown]
# #### Exemplo do conjunto de dados de treinamento

# %%
fig, axs = plt.subplots(5,10, figsize=(19, 10), facecolor='w', edgecolor='k')
fig.subplots_adjust(hspace = .2, wspace=.0001)
axs = axs.ravel()

for i in range(50):
    axs[i].imshow(train_x_conv.squeeze()[i], cmap='gray')
    axs[i].set_title(train_y.loc[i,train_y.loc[i]==1].index[0])
    axs[i].axis('off')

# %% [markdown]
# ### Padronização do conjunto de dados

# %%
train_x_conv = train_x_conv.astype('float32') / 255
validation_x_conv  = validation_x_conv.astype('float32') / 255
test_x_conv = test_x_conv.astype('float32') / 255

# %%
num_classes = train_y.shape[1]
print(num_classes)

input_shape = (1, shape, shape)
# Out:
# 7

# %% [markdown]
# _____
# ## Rede Neural Convolucional
#
# Abaixo será implementada uma rede neural convolucional simples, a fim de avaliar previamente o desempenho no conjunto de dados e, posteriormente, outros modelos serão aplicados. Para abrir o ``Tensorboard``:

# %% [raw]
# https://cloud.google.com/tpu/docs/quickstart
# executar no prompt: tensorboard --logdir "E:/Mestrado/Disciplinas/201802 - MO444 - Aprendizado de Máquina e Reconhecimento de Padrões/Projeto/Programas/TensorBoard/"
# abrir no navegador http://<your-ip>:6006, no meu caso, http://desktop-4pqid90:6006/

# %%
def CNN_Simples(input_shape):
    
    model = Sequential()
    model.add(Conv2D(32, (5, 5), input_shape=input_shape, data_format="channels_first"))
    model.add(Activation('relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))

    model.add(Conv2D(64, (3, 3)))  
    model.add(Activation('relu'))
    model.add(Dropout(0.1))
    model.add(MaxPooling2D(pool_size=(2, 2)))

    model.add(Conv2D(128, (3, 3)))
    model.add(Activation('relu'))
    model.add(Dropout(0.1))
    model.add(MaxPooling2D(pool_size=(2, 2)))

    model.add(Flatten())

    model.add(Dense(1024))
    model.add(Activation('relu'))
    model.add(Dropout(0.5))

    model.add(Dense(512))
    model.add(Activation('relu'))
    model.add(Dropout(0.5))

    model.add(Dense(num_classes))
    model.add(Activation('softmax')) #Probabilidade de cada classe
    
    
    return model

# %% [markdown]
# Camadas do modelo:

# %%
model = CNN_Simples(input_shape)
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_4 (Conv2D)            (None, 32, 56, 56)        832
# _________________________________________________________________
# activation_7 (Activation)    (None, 32, 56, 56)        0
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 16, 28, 56)        0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 14, 26, 64)        32320
# _________________________________________________________________
# activation_8 (Activation)    (None, 14, 26, 64)        0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 14, 26, 64)        0
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 7, 13, 64)         0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 5, 11, 128)        73856
# _________________________________________________________________
# activation_9 (Activation)    (None, 5, 11, 128)        0
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 5, 11, 128)        0
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 2, 5, 128)         0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 1280)              0
# _________________________________________________________________
# dense_4 (Dense)              (None, 1024)              1311744
# _________________________________________________________________
# activation_10 (Activation)   (None, 1024)              0
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_5 (Dense)              (None, 512)               524800
# _________________________________________________________________
# activation_11 (Activation)   (None, 512)               0
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_6 (Dense)              (None, 7)                 3591
# _________________________________________________________________
# activation_12 (Activation)   (None, 7)                 0
# =================================================================
# Total params: 1,947,143
# Trainable params: 1,947,143
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Compilando o modelo

# %%
# https://www.davidtvs.com/keras-custom-metrics/

class AccNorm(object):
    def __init__(self, num_classes):
        super().__init__()
        self.num_classes = num_classes

    def acc_norm(self, y_true, y_pred):
        # Wraps np_mean_iou method and uses it as a TensorFlow op.
        # Takes numpy arrays as its arguments and returns numpy arrays as
        # its outputs.
        
        return tf.py_func(self.np_acc_norm, [y_true, y_pred], tf.float32)        

    
    def np_acc_norm(self, y_true, y_pred):
        # Compute the confusion matrix to get the number of true positives,
        # false positives, and false negatives
        # Convert predictions and target from categorical to integer format
        target = np.argmax(y_true, axis=-1).ravel()
        predicted = np.argmax(y_pred, axis=-1).ravel()

        # Trick from torchnet for bincounting 2 arrays together
        # https://github.com/pytorch/tnt/blob/master/torchnet/meter/confusionmeter.py
        x = predicted + self.num_classes * target
        bincount_2d = np.bincount(x.astype(np.int32), minlength=self.num_classes**2)
        assert bincount_2d.size == self.num_classes**2
        conf = bincount_2d.reshape((self.num_classes, self.num_classes))

        # Compute the IoU and mean IoU from the confusion matrix
        true_positive = np.diag(conf)
        total = np.sum(conf, 1)
        false_positive = np.sum(conf, 0) - true_positive
        false_negative = np.sum(conf, 1) - true_positive

        # Just in case we get a division by 0, ignore/hide the error and set the value to 0
        with np.errstate(divide='ignore', invalid='ignore'):
            iou = true_positive / total #(true_positive + false_positive + false_negative)
        iou[np.isnan(iou)] = 0
#         print('conf: \n', conf, '\n true_positive: \n', true_positive, '\n total: \n', total, '\n iou: \n',iou)
#         print('acc: ',np.mean(iou).astype(np.float32))
        return np.mean(iou).astype(np.float32)

num_classes = 7
acc_metric = AccNorm(num_classes)

# %%
# https://github.com/keras-team/keras/issues/10426
model.compile(loss='categorical_crossentropy', optimizer="adam", metrics=["accuracy",acc_metric.acc_norm])

# %%
num_epoch = 500
num_batch = 1024

checkpointer   = ModelCheckpoint(filepath=os.path.join('./Modelos/cnn_simples_emocoes_weights_preproc.h5'), verbose=1, save_best_only=True, monitor='val_acc_norm')
csv_logger     = CSVLogger(os.path.join('./Modelos/cnn_simples_training_preproc.log'))
early_stopping = EarlyStopping(monitor='val_acc_norm', min_delta=0, patience=5, verbose=1, mode='max')
tensorboard = TensorBoard('./TensorBoard/CNN Simples - Pré-processamento',  write_graph=True, write_images=False)

model_history = model.fit(train_x_conv, train_y, epochs=num_epoch, batch_size=num_batch, shuffle=True, validation_data=(validation_x_conv, validation_y), verbose=1, callbacks=[tensorboard, early_stopping, checkpointer, csv_logger])
# Out:
# Train on 20473 samples, validate on 2560 samples
# Epoch 1/500
# 20473/20473 [==============================] - 92s 4ms/step - loss: 1.7685 - acc: 0.2843 - acc_norm: 0.1440 - val_loss: 1.7145 - val_acc: 0.2855 - val_acc_norm: 0.1432
#
# Epoch 00001: val_acc_norm improved from -inf to 0.14316, saving model to ./Modelos/cnn_simples_emocoes_weights_preproc.h5
# Epoch 2/500
# 20473/20473 [==============================] - 82s 4ms/step - loss: 1.6534 - acc: 0.3646 - acc_norm: 0.2295 - val_loss: 1.5716 - val_acc: 0.4012 - val_acc_norm: 0.2759
#
# Epoch 00002: val_acc_norm improved from 0.14316 to 0.27586, saving model to ./Modelos/cnn_simples_emocoes_weights_preproc.h5
# Epoch 3/500
# 20473/20473 [==============================] - 84s 4ms/step - loss: 1.5395 - acc: 0.4180 - acc_norm: 0.2885 - val_loss: 1.4722 - val_acc: 0.4496 - val_acc_norm: 0.3318
#
# Epoch 00003: val_acc_norm improved from 0.27586 to 0.33176, saving model to ./Modelos/cnn_simples_emocoes_weights_preproc.h5
# Epoch 4/500
# 20473/20473 [==============================] - 84s 4ms/step - loss: 1.4388 - acc: 0.4564 - acc_norm: 0.3298 - val_loss: 1.3769 - val_acc: 0.4633 - val_acc_norm: 0.3278
#
# Epoch 00004: val_acc_norm did not improve from 0.33176
# Epoch 5/500
# 20473/20473 [==============================] - 70s 3ms/step - loss: 1.3434 - acc: 0.4883 - acc_norm: 0.3624 - val_loss: 1.2903 - val_acc: 0.4871 - val_acc_norm: 0.3629
#
# Epoch 00005: val_acc_norm improved from 0.33176 to 0.36286, saving model to ./Modelos/cnn_simples_emocoes_weights_preproc.h5
# Epoch 6/500
# 20473/20473 [==============================] - 88s 4ms/step - loss: 1.2867 - acc: 0.5106 - acc_norm: 0.3865 - val_loss: 1.2544 - val_acc: 0.5070 - val_acc_norm: 0.3808
#
# Epoch 00006: val_acc_norm improved from 0.36286 to 0.38079, saving model to ./Modelos/cnn_simples_emocoes_weights_preproc.h5
# Epoch 7/500
# 20473/20473 [==============================] - 53s 3ms/step - loss: 1.2294 - acc: 0.5350 - acc_norm: 0.4115 - val_loss: 1.2177 - val_acc: 0.5242 - val_acc_norm: 0.4057
#
# Epoch 00007: val_acc_norm improved from 0.38079 to 0.40568, saving model to ./Modelos/cnn_simples_emocoes_weights_preproc.h5
# Epoch 8/500
# 20473/20473 [==============================] - 16s 795us/step - loss: 1.1918 - acc: 0.5471 - acc_norm: 0.4250 - val_loss: 1.1964 - val_acc: 0.5375 - val_acc_norm: 0.4111
#
# Epoch 00008: val_acc_norm improved from 0.40568 to 0.41109, saving model to ./Modelos/cnn_simples_emocoes_weights_preproc.h5
# Epoch 9/500
# 20473/20473 [==============================] - 49s 2ms/step - loss: 1.1559 - acc: 0.5637 - acc_norm: 0.4406 - val_loss: 1.1704 - val_acc: 0.5531 - val_acc_norm: 0.4401
#
# Epoch 00009: val_acc_norm improved from 0.41109 to 0.44009, saving model to ./Modelos/cnn_simples_emocoes_weights_preproc.h5
# Epoch 10/500
# 20473/20473 [==============================] - 89s 4ms/step - loss: 1.1102 - acc: 0.5856 - acc_norm: 0.4632 - val_loss: 1.1378 - val_acc: 0.5563 - val_acc_norm: 0.4381
#
# Epoch 00010: val_acc_norm did not improve from 0.44009
# Epoch 11/500
# 20473/20473 [==============================] - 89s 4ms/step - loss: 1.0668 - acc: 0.6003 - acc_norm: 0.4765 - val_loss: 1.1222 - val_acc: 0.5641 - val_acc_norm: 0.4507
#
# Epoch 00011: val_acc_norm improved from 0.44009 to 0.45074, saving model to ./Modelos/cnn_simples_emocoes_weights_preproc.h5
# Epoch 12/500
# 20473/20473 [==============================] - 91s 4ms/step - loss: 1.0416 - acc: 0.6094 - acc_norm: 0.4856 - val_loss: 1.1253 - val_acc: 0.5797 - val_acc_norm: 0.4599
#
# Epoch 00012: val_acc_norm improved from 0.45074 to 0.45994, saving model to ./Modelos/cnn_simples_emocoes_weights_preproc.h5
# Epoch 13/500
# 20473/20473 [==============================] - 86s 4ms/step - loss: 1.0030 - acc: 0.6251 - acc_norm: 0.5036 - val_loss: 1.0968 - val_acc: 0.5848 - val_acc_norm: 0.4675
#
# Epoch 00013: val_acc_norm improved from 0.45994 to 0.46745, saving model to ./Modelos/cnn_simples_emocoes_weights_preproc.h5
# Epoch 14/500
# 20473/20473 [==============================] - 15s 746us/step - loss: 0.9696 - acc: 0.6367 - acc_norm: 0.5154 - val_loss: 1.0975 - val_acc: 0.5902 - val_acc_norm: 0.4773
#
# Epoch 00014: val_acc_norm improved from 0.46745 to 0.47731, saving model to ./Modelos/cnn_simples_emocoes_weights_preproc.h5
# Epoch 15/500
# 20473/20473 [==============================] - 14s 692us/step - loss: 0.9538 - acc: 0.6441 - acc_norm: 0.5278 - val_loss: 1.0952 - val_acc: 0.5875 - val_acc_norm: 0.4789
#
# Epoch 00015: val_acc_norm improved from 0.47731 to 0.47892, saving model to ./Modelos/cnn_simples_emocoes_weights_preproc.h5
# Epoch 16/500
# 20473/20473 [==============================] - 14s 697us/step - loss: 0.9149 - acc: 0.6620 - acc_norm: 0.5478 - val_loss: 1.0942 - val_acc: 0.5930 - val_acc_norm: 0.5003
#
# Epoch 00016: val_acc_norm improved from 0.47892 to 0.50030, saving model to ./Modelos/cnn_simples_emocoes_weights_preproc.h5
# Epoch 17/500
# 20473/20473 [==============================] - 14s 694us/step - loss: 0.8707 - acc: 0.6763 - acc_norm: 0.5714 - val_loss: 1.0991 - val_acc: 0.5977 - val_acc_norm: 0.5079
#
# Epoch 00017: val_acc_norm improved from 0.50030 to 0.50788, saving model to ./Modelos/cnn_simples_emocoes_weights_preproc.h5
# Epoch 18/500
# 20473/20473 [==============================] - 21s 1ms/step - loss: 0.8429 - acc: 0.6911 - acc_norm: 0.5913 - val_loss: 1.0902 - val_acc: 0.5961 - val_acc_norm: 0.5002
#
# Epoch 00018: val_acc_norm did not improve from 0.50788
# Epoch 19/500
# 20473/20473 [==============================] - 23s 1ms/step - loss: 0.8069 - acc: 0.7048 - acc_norm: 0.6127 - val_loss: 1.0956 - val_acc: 0.6008 - val_acc_norm: 0.5288
#
# Epoch 00019: val_acc_norm improved from 0.50788 to 0.52883, saving model to ./Modelos/cnn_simples_emocoes_weights_preproc.h5
# Epoch 20/500
# 20473/20473 [==============================] - 23s 1ms/step - loss: 0.7740 - acc: 0.7160 - acc_norm: 0.6303 - val_loss: 1.1286 - val_acc: 0.5980 - val_acc_norm: 0.5189
#
# Epoch 00020: val_acc_norm did not improve from 0.52883
# Epoch 21/500
# 20473/20473 [==============================] - 23s 1ms/step - loss: 0.7554 - acc: 0.7248 - acc_norm: 0.6489 - val_loss: 1.0857 - val_acc: 0.6023 - val_acc_norm: 0.5192
#
# Epoch 00021: val_acc_norm did not improve from 0.52883
# Epoch 22/500
# 20473/20473 [==============================] - 23s 1ms/step - loss: 0.7188 - acc: 0.7407 - acc_norm: 0.6644 - val_loss: 1.1032 - val_acc: 0.6102 - val_acc_norm: 0.5560
#
# Epoch 00022: val_acc_norm improved from 0.52883 to 0.55599, saving model to ./Modelos/cnn_simples_emocoes_weights_preproc.h5
# Epoch 23/500
# 20473/20473 [==============================] - 23s 1ms/step - loss: 0.6859 - acc: 0.7525 - acc_norm: 0.6873 - val_loss: 1.1305 - val_acc: 0.6141 - val_acc_norm: 0.5512
#
# Epoch 00023: val_acc_norm did not improve from 0.55599
# Epoch 24/500
# 20473/20473 [==============================] - 23s 1ms/step - loss: 0.6627 - acc: 0.7583 - acc_norm: 0.6895 - val_loss: 1.1248 - val_acc: 0.6090 - val_acc_norm: 0.5467
#
# Epoch 00024: val_acc_norm did not improve from 0.55599
# Epoch 25/500
# 20473/20473 [==============================] - 23s 1ms/step - loss: 0.6277 - acc: 0.7747 - acc_norm: 0.7095 - val_loss: 1.1372 - val_acc: 0.6074 - val_acc_norm: 0.5528
#
# Epoch 00025: val_acc_norm did not improve from 0.55599
# Epoch 26/500
# 20473/20473 [==============================] - 23s 1ms/step - loss: 0.6022 - acc: 0.7854 - acc_norm: 0.7224 - val_loss: 1.1741 - val_acc: 0.6078 - val_acc_norm: 0.5514
#
# Epoch 00026: val_acc_norm did not improve from 0.55599
# Epoch 27/500
# 20473/20473 [==============================] - 23s 1ms/step - loss: 0.5738 - acc: 0.7941 - acc_norm: 0.7319 - val_loss: 1.1602 - val_acc: 0.6238 - val_acc_norm: 0.5629
#
# Epoch 00027: val_acc_norm improved from 0.55599 to 0.56289, saving model to ./Modelos/cnn_simples_emocoes_weights_preproc.h5
# Epoch 28/500
# 20473/20473 [==============================] - 23s 1ms/step - loss: 0.5516 - acc: 0.8003 - acc_norm: 0.7472 - val_loss: 1.1498 - val_acc: 0.6230 - val_acc_norm: 0.5717
#
# Epoch 00028: val_acc_norm improved from 0.56289 to 0.57172, saving model to ./Modelos/cnn_simples_emocoes_weights_preproc.h5
# Epoch 29/500
# 20473/20473 [==============================] - 23s 1ms/step - loss: 0.5217 - acc: 0.8114 - acc_norm: 0.7534 - val_loss: 1.1642 - val_acc: 0.6305 - val_acc_norm: 0.5730
# Epoch 00029: val_acc_norm improved from 0.57172 to 0.57303, saving model to ./Modelos/cnn_simples_emocoes_weights_preproc.h5
# Epoch 30/500
# 20473/20473 [==============================] - 23s 1ms/step - loss: 0.4923 - acc: 0.8232 - acc_norm: 0.7809 - val_loss: 1.2596 - val_acc: 0.6164 - val_acc_norm: 0.5676
#
# Epoch 00030: val_acc_norm did not improve from 0.57303
# Epoch 31/500
# 20473/20473 [==============================] - 23s 1ms/step - loss: 0.4830 - acc: 0.8281 - acc_norm: 0.7830 - val_loss: 1.2943 - val_acc: 0.6133 - val_acc_norm: 0.5546
#
# Epoch 00031: val_acc_norm did not improve from 0.57303
# Epoch 32/500
# 20473/20473 [==============================] - 23s 1ms/step - loss: 0.4567 - acc: 0.8381 - acc_norm: 0.8006 - val_loss: 1.2434 - val_acc: 0.6227 - val_acc_norm: 0.5803
#
# Epoch 00032: val_acc_norm improved from 0.57303 to 0.58033, saving model to ./Modelos/cnn_simples_emocoes_weights_preproc.h5
# Epoch 33/500
# 20473/20473 [==============================] - 23s 1ms/step - loss: 0.4346 - acc: 0.8440 - acc_norm: 0.8092 - val_loss: 1.2714 - val_acc: 0.6188 - val_acc_norm: 0.5841
#
# Epoch 00033: val_acc_norm improved from 0.58033 to 0.58409, saving model to ./Modelos/cnn_simples_emocoes_weights_preproc.h5
# Epoch 34/500
# 20473/20473 [==============================] - 24s 1ms/step - loss: 0.4083 - acc: 0.8562 - acc_norm: 0.8144 - val_loss: 1.3088 - val_acc: 0.6238 - val_acc_norm: 0.5812
#
# Epoch 00034: val_acc_norm did not improve from 0.58409
# Epoch 35/500
# 20473/20473 [==============================] - 27s 1ms/step - loss: 0.3932 - acc: 0.8612 - acc_norm: 0.8265 - val_loss: 1.3093 - val_acc: 0.6238 - val_acc_norm: 0.5784
#
# Epoch 00035: val_acc_norm did not improve from 0.58409
# Epoch 36/500
# 20473/20473 [==============================] - 31s 1ms/step - loss: 0.3722 - acc: 0.8680 - acc_norm: 0.8355 - val_loss: 1.3173 - val_acc: 0.6188 - val_acc_norm: 0.5769
#
# Epoch 00036: val_acc_norm did not improve from 0.58409
# Epoch 37/500
# 20473/20473 [==============================] - 31s 1ms/step - loss: 0.3655 - acc: 0.8701 - acc_norm: 0.8410 - val_loss: 1.3063 - val_acc: 0.6301 - val_acc_norm: 0.5831
#
# Epoch 00037: val_acc_norm did not improve from 0.58409
# Epoch 38/500
# 20473/20473 [==============================] - 30s 1ms/step - loss: 0.3588 - acc: 0.8730 - acc_norm: 0.8478 - val_loss: 1.3744 - val_acc: 0.6234 - val_acc_norm: 0.5825
#
# Epoch 00038: val_acc_norm did not improve from 0.58409
# Epoch 00038: early stopping

# %%
# Probabilidades de cada classe
predito = model.predict_classes(train_x_conv)
predito_new = model.predict_classes(validation_x_conv)

obs = np.argmax(train_y.values,axis=1)
obs_new = np.argmax(validation_y.values,axis=1)

classes = ['Angry','Disgust','Fear','Happy','Sad','Surprise','Neutral']

# %% [markdown]
# ### Calcula a matriz de confusão:

# %%
fig1, axes1 = plt.subplots(nrows=1, ncols=1,figsize=(12,6))
graf_confusion_new = plot_confusion_matrix(confusion_matrix(obs,predito), normalize = False, classes=classes,title="Matriz de confusão - Treinamento")
axes1.grid(b=False)

fig2, axes2 = plt.subplots(nrows=1, ncols=1,figsize=(12,6))
graf_confusion_new = plot_confusion_matrix(confusion_matrix(obs_new,predito_new), normalize = False, classes=classes,title="Matriz de confusão - Validação")
axes2.grid(b=False)

# %% [markdown]
# ### Gráfico das métricas em cada epoch

# %%
fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(25,5))
plt.suptitle('Desempenho para o conjunto de treinamento e validação', fontsize=15, fontweight='bold')
axes[0].plot(model_history.history['loss'],marker='.')
axes[0].plot(model_history.history['val_loss'],marker='.')
axes[0].set_title('Função de Perda')
axes[0].set_ylabel('Loss')
axes[0].set_xlabel('Epoch')
axes[0].legend(['Treinamento', 'Validação'], loc='upper right')

axes[1].plot(model_history.history['acc'],marker='.')
axes[1].plot(model_history.history['val_acc'],marker='.')
axes[1].set_title('Acurácia')
axes[1].set_ylabel('Acurácia')
axes[1].set_xlabel('Epoch')
axes[1].legend(['Treinamento', 'Validação'], loc='upper left')

axes[2].plot(model_history.history['acc_norm'],marker='.')
axes[2].plot(model_history.history['val_acc_norm'],marker='.')
axes[2].set_title('Acurácia Normalizada')
axes[2].set_ylabel('Acurácia Normalizada')
axes[2].set_xlabel('Epoch')
axes[2].legend(['Treinamento', 'Validação'], loc='upper left')

# %% [markdown]
# ------
# ## Aplicando o modelo no conjunto de teste

# %%
from keras.models import load_model

# returns a compiled model identical to the previous one
model = load_model('./Modelos/cnn_simples_emocoes_weights_preproc.h5', custom_objects={'acc_norm': acc_metric.acc_norm})

# %%
# Probabilidades de cada classe
predito = model.predict_classes(train_x_conv)
predito_new = model.predict_classes(validation_x_conv)
predito_new_tst = model.predict_classes(test_x_conv)

obs = np.argmax(train_y.values,axis=1)
obs_new = np.argmax(validation_y.values,axis=1)
obs_new_tst = np.argmax(test_y.values,axis=1)

classes = ['Angry','Disgust','Fear','Happy','Sad','Surprise','Neutral']

fig1, axes1 = plt.subplots(nrows=1, ncols=1,figsize=(12,6))
graf_confusion_new = plot_confusion_matrix(confusion_matrix(obs,predito), normalize = False, classes=classes,title="Matriz de confusão - Treinamento pré-processado (CNN)")
axes1.grid(b=False)

fig2, axes2 = plt.subplots(nrows=1, ncols=1,figsize=(12,6))
graf_confusion_new = plot_confusion_matrix(confusion_matrix(obs_new,predito_new), normalize = False, classes=classes,title="Matriz de confusão - Validação pré-processado (CNN)")
axes2.grid(b=False)

fig3, axes3 = plt.subplots(nrows=1, ncols=1,figsize=(12,6))
graf_confusion_new = plot_confusion_matrix(confusion_matrix(obs_new_tst,predito_new_tst), normalize = False, classes=classes,title="Matriz de confusão - Teste pré-processado (CNN)")
axes3.grid(b=False)

# %% [markdown]
# ### Conjunto de dados sem modificação

# %%
dados = pd.DataFrame(pd.read_csv('Dados/fer2013/fer2013.csv'))
dados['pixels'] = dados['pixels'].apply(lambda x: np.fromstring(x,sep=' '))

# %%
print('===================================')
print('          Dados originais          ')
print('===================================')
print('-----------------------------------')
print('Conjunto de teste:')
test = dados.loc[dados['Usage'] == 'PrivateTest']
# test = test.sample(300)
test_x = np.vstack(test['pixels'].values)
test_y = pd.get_dummies(test['emotion'])
test_y.columns = ['Angry','Disgust','Fear','Happy','Sad','Surprise','Neutral']
print('X: {}, y: {}'.format(test_x.shape,test_y.shape))
print('-----------------------------------')
print('===================================')

print('\n')
print('===================================')
print('       Dados para modelagem        ')
print('===================================')
print('-----------------------------------')
print('Conjunto de teste:')
test_x_conv = np.reshape(test_x,(-1, 48, 48))
print('X: {}'.format(test_x_conv.shape))
print('-----------------------------------')
print('===================================')
# Out:
# ===================================
#           Dados originais
# ===================================
# -----------------------------------
# Conjunto de teste:
# X: (3589, 2304), y: (3589, 7)
# -----------------------------------
# ===================================
#
#
# ===================================
#        Dados para modelagem
# ===================================
# -----------------------------------
# Conjunto de teste:
# X: (3589, 48, 48)
# -----------------------------------
# ===================================

# %%
shape_new = 60

test_x_alt = []

for im_test in test_x_conv:
    test_x_alt.append(cv2.resize(np.asarray(im_test), (shape_new,shape_new),interpolation=cv2.INTER_CUBIC))
    
test_x_conv = np.asarray(test_x_alt).astype('float32')/ 255
test_x_conv = np.reshape(test_x_conv,(-1, 1, shape_new, shape_new))    

# Probabilidades de cada classe
predito_new_tst = model.predict_classes(test_x_conv)
obs_new_tst = np.argmax(test_y.values,axis=1)

classes = ['Angry','Disgust','Fear','Happy','Sad','Surprise','Neutral']

fig1, axes1 = plt.subplots(nrows=1, ncols=1,figsize=(12,6))
graf_confusion_new = plot_confusion_matrix(confusion_matrix(obs_new_tst,predito_new_tst), normalize = False, classes=classes,title="Matriz de confusão - Teste")
axes1.grid(b=False)
